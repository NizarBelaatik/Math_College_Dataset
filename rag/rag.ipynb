# %%
import json
import os 
OUTPUT_DIR = "../output"

dataset_location = os.path.join(OUTPUT_DIR, "math_dataset_corr_ai.jsonl")

# Load and clean your JSONL dataset
docs = []
with open("math_dataset.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        data = json.loads(line)
        question = data.get("question", "")
        correction = data.get("explanation", "")#raw_correction
        combined = f"Question:\n{question}\n\nCorrection:\n{correction}"
        docs.append(combined)

# %%
pip install sentence-transformers faiss-cpu
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (4.1.0)
# Requirement already satisfied: faiss-cpu in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (1.11.0)
# Requirement already satisfied: tqdm in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: Pillow in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: scikit-learn in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: scipy in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sentence-transformers) (0.32.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: requests in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.5.1)
# Requirement already satisfied: filelock in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: colorama in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\night\documents\111project\math_college_dataset\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\night\Documents\111Project\Math_College_Dataset\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import json
import os 
OUTPUT_DIR = "../output"

dataset_location = os.path.join(OUTPUT_DIR, "math_dataset_corr_ai.jsonl")

# Load and clean your JSONL dataset
docs = []
with open("math_dataset.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        data = json.loads(line)
        question = data.get("question", "")
        correction = data.get("explanation", "")#raw_correction
        combined = f"Question:\n{question}\n\nCorrection:\n{correction}"
        docs.append(combined)



#Embed and store documents
# 
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# Load embedding model
model = SentenceTransformer("BAAI/bge-small-en-v1.5")

# Compute embeddings
embeddings = model.encode(docs, show_progress_bar=True)

# Create FAISS index
dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(np.array(embeddings))

# Save index
faiss.write_index(index, "math_index.faiss")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 9
#       7 # Load and clean your JSONL dataset
#       8 docs = []
# ----> 9 with open("math_dataset.jsonl", "r", encoding="utf-8") as f:
#      10     for line in f:
#      11         data = json.loads(line)
#
# File c:\Users\night\Documents\111Project\Math_College_Dataset\venv\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'math_dataset.jsonl'
